# %% [markdown]
# <a href="https://colab.research.google.com/github/tatagroups1234/emotion-recognition/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np 
import os
import cv2
from tqdm import tqdm
#/content/drive/MyDrive/probe/fer2013.csv
data = pd.read_csv("drive/MyDrive/probes/fer2013.csv")

#data = pd.read_csv("https://drive.google.com/file/d/1PpaJ8vAvw_6lK0Tu8_0xwMtyrmNIAodc/view?usp=sharing.csv")
data.head()


labels = []
usage = []

for i in data["emotion"]:
    labels.append(i)
    
for i in data["Usage"]:
    usage.append(i)
    
print(set(labels))
print(set(usage))



count0 = 0
count1 = 0
count2 = 0
count3 = 0
count4 = 0
count5 = 0
count6 = 0

for i, j, k in tqdm(zip(data["emotion"], data["pixels"], data["Usage"])):
    pixel = []
    #print(pixel)
    pixels = j.split(' ')
    for m in pixels:
        value = float(m)
        pixel.append(value)
    pixel = np.array(pixel)
    image = pixel.reshape(48, 48)
    
    if k == "Training":
        if not os.path.exists("drive/MyDrive/probes/train"):
            os.mkdir("drive/MyDrive/probes/train")
        if i == 0:
            if not os.path.exists("drive/MyDrive/probes/train/Angry"):
                os.mkdir("drive/MyDrive/probes/train/Angry")
                path = "drive/MyDrive/probes/train/Angry/" + str(count0) + ".jpg"
                cv2.imwrite(path , image)
                count0 += 1
            else:
                path = "drive/MyDrive/probes/train/Angry/" + str(count0) + ".jpg"
                cv2.imwrite(path , image)
                count0 += 1    
    # if k == "Training":
    #     if not os.path.exists("drive/MyDrive/probes/train"):
    #       os.mkdir("drive/MyDrive/probes/train")

            
    #     if i == 0:
    #         if not os.path.exists("drive/MyDrive/probes/train/Angry"):
    #             os.mkdir("drive/MyDrive/probes/train/Angry")
    #             path = "drive/MyDrive/probes/train/Angry/" + str(count0) + ".jpg"
    #             cv2.imwrite(path , image)
    #             count0 += 1
    #         else:
    #             path = "drive/MyDrive/probes/train/Angry/" + str(count0) + ".jpg"
    #             cv2.imwrite(path , image)
    #             count0 += 1
        # if i == 1:
        #     if not os.path.exists("drive/MyDrive/probe/train/Disgust"):
        #         os.mkdir("drive/MyDrive/probe/train/Disgust")
        #         path = "drive/MyDrive/probe/train/Disgust/" + str(count1) + ".jpg"
        #         cv2.imwrite(path , image)
        #         count1 += 1
        #     else:
        #         path = "drive/MyDrive/probe/train/Disgust/" + str(count1) + ".jpg"
        #         cv2.imwrite(path , image)
        #         count1 += 1
        if i == 2:
            if not os.path.exists("drive/MyDrive/probes/train/Fear"):
                os.mkdir("drive/MyDrive/probes/train/Fear")
                path = "drive/MyDrive/probes/train/Fear/" + str(count2) + ".jpg"
                cv2.imwrite(path , image)
                count2 += 1
            else:
                path = "drive/MyDrive/probes/train/Fear/" + str(count2) + ".jpg"
                cv2.imwrite(path , image)
                count2 += 1
        if i == 3:
            if not os.path.exists("drive/MyDrive/probes/train/Happy"):
                os.mkdir("drive/MyDrive/probes/train/Happy")
                path = "drive/MyDrive/probes/train/Happy/" + str(count3) + ".jpg"
                cv2.imwrite(path , image)
                count3 += 1
            else:
                path = "drive/MyDrive/probes/train/Happy/" + str(count3) + ".jpg"
                cv2.imwrite(path , image)
                count3 += 1
        if i == 4:
            if not os.path.exists("drive/MyDrive/probes/train/Sad"):
                os.mkdir("drive/MyDrive/probes/train/Sad")
                path = "drive/MyDrive/probes/train/Sad/" + str(count4) + ".jpg"
                cv2.imwrite(path , image)
                count4 += 1
            else:
                path = "drive/MyDrive/probes/train/Sad/" + str(count4) + ".jpg"
                cv2.imwrite(path , image)
                count4 += 1
        if i == 5:
            if not os.path.exists("drive/MyDrive/probes/train/Surprise"):
                os.mkdir("drive/MyDrive/probes/train/Surprise")
                path = "drive/MyDrive/probes/train/Surprise/" + str(count5) + ".jpg"
                cv2.imwrite(path , image)
                count5 += 1
            else:
                path = "drive/MyDrive/probes/train/Surprise/" + str(count5) + ".jpg"
                cv2.imwrite(path , image)
                count5 += 1
        if i == 6:
            if not os.path.exists("drive/MyDrive/probes/train/Neutral"):
                os.mkdir("drive/MyDrive/probes/train/Neutral")
                path = "drive/MyDrive/probes/train/Neutral/" + str(count6) + ".jpg"
                cv2.imwrite(path , image)
                count6 += 1
            else:
                path = "drive/MyDrive/probes/train/Neutral/" + str(count6) + ".jpg"
                cv2.imwrite(path , image)
                count6 += 1
    else:
        if not os.path.exists("drive/MyDrive/probes/validation"):
            os.mkdir("drive/MyDrive/probes/validation")
        if i == 0:
            if not os.path.exists("drive/MyDrive/probes/validation/Angry"):
                os.mkdir("drive/MyDrive/probes/validation/Angry")
                path = "drive/MyDrive/probes/validation/Angry/" + str(count0) + ".jpg"
                cv2.imwrite(path , image)
                count0 += 1
            else:
                path = "drive/MyDrive/probes/validation/Angry/" + str(count0) + ".jpg"
                cv2.imwrite(path , image)
                count0 += 1
        # if i == 1:
        #     if not os.path.exists("drive/MyDrive/probe/validation/Disgust"):
        #         os.mkdir("drive/MyDrive/probe/validation/Disgust")
        #         path = "drive/MyDrive/probe/validation/Disgust/" + str(count1) + ".jpg"
        #         cv2.imwrite(path , image)
        #         count1 += 1
        #     else:
        #         path = "drive/MyDrive/probe/validation/Disgust/" + str(count1) + ".jpg"
        #         cv2.imwrite(path , image)
        #         count1 += 1
        if i == 2:
            if not os.path.exists("drive/MyDrive/probes/validation/Fear"):
                os.mkdir("drive/MyDrive/probes/validation/Fear")
                path = "drive/MyDrive/probes/validation/Fear/" + str(count2) + ".jpg"
                cv2.imwrite(path , image)
                count2 += 1
            else:
                path = "drive/MyDrive/probes/validation/Fear/" + str(count2) + ".jpg"
                cv2.imwrite(path , image)
                count2 += 1
        if i == 3:
            if not os.path.exists("drive/MyDrive/probes/validation/Happy"):
                os.mkdir("drive/MyDrive/probes/validation/Happy")
                path = "drive/MyDrive/probes/validation/Happy/" + str(count3) + ".jpg"
                cv2.imwrite(path , image)
                count3 += 1
            else:
                path = "drive/MyDrive/probes/validation/Happy/" + str(count3) + ".jpg"
                cv2.imwrite(path , image)
                count3 += 1
        if i == 4:
            if not os.path.exists("drive/MyDrive/probes/validation/Sad"):
                os.mkdir("drive/MyDrive/probes/validation/Sad")
                path = "drive/MyDrive/probes/validation/Sad/" + str(count4) + ".jpg"
                cv2.imwrite(path , image)
                count4 += 1
            else:
                path = "drive/MyDrive/probes/validation/Sad/" + str(count4) + ".jpg"
                cv2.imwrite(path , image)
                count4 += 1
        if i == 5:
            if not os.path.exists("drive/MyDrive/probes/validation/Surprise"):
                os.mkdir("drive/MyDrive/probes/validation/Surprise")
                path = "drive/MyDrive/probes/validation/Surprise/" + str(count5) + ".jpg"
                cv2.imwrite(path , image)
                count5 += 1
            else:
                path = "drive/MyDrive/probes/validation/Surprise/" + str(count5) + ".jpg"
                cv2.imwrite(path , image)
                count5 += 1
        if i == 6:
            if not os.path.exists("drive/MyDrive/probes/validation/Neutral"):
                os.mkdir("drive/MyDrive/probes/validation/Neutral")
                path = "drive/MyDrive/probes/validation/Neutral/" + str(count6) + ".jpg"
                cv2.imwrite(path , image)
                count6 += 1
            else:
                path = "drive/MyDrive/probes/validation/Neutral/" + str(count6) + ".jpg"
                cv2.imwrite(path , image)
                count6 += 1
# Out:
# {0, 1, 2, 3, 4, 5, 6}
# {'Training', 'PublicTest', 'PrivateTest'}
# 35887it [04:45, 125.83it/s]

# %%
import os
import matplotlib.pyplot as plt


train_directory = "drive/MyDrive/probes/train/"
train_dir = os.listdir(train_directory)
classes = []

for folder in train_dir:
    classes.append(folder)

train_counts = []

for folder in train_dir:
    class_path = train_directory + folder + "/"
    list_train = []
    count = 0
    for file in os.listdir(class_path):
        count +=1
    
    train_counts.append(count)
    
train_counts


plt.bar(classes, train_counts, width=0.5)
plt.title("Bar Graph of Train Data")
plt.xlabel("Classes")
plt.ylabel("Counts")



plt.scatter(classes, train_counts)
plt.plot(classes, train_counts, '-o')
plt.show()

# %%
import shutil
 
shutil.rmtree("drive/MyDrive/probe/validation/Disgust/")

# %%
from google.colab.patches import cv2_imshow

image = cv2.imread("/content/drive/MyDrive/probe/validation/Disgust/0.jpg")

cv2_imshow(image)

# %%
import keras
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, BatchNormalization, Dense, Flatten, Activation
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
import numpy as np
import pydot_ng
import graphviz
import os

num_classes = 6

Img_Height = 48
Img_width = 48

batch_size = 32
train_directory = "drive/MyDrive/probes/train"
train_dir = os.listdir(train_directory)
validation_directory = "drive/MyDrive/probes/validation"
validation_dir = os.listdir(validation_directory)

#train_dir = "train"
#validation_dir = "validation"




train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=60,
                                   shear_range=0.5,
                                   zoom_range=0.5,
                                   width_shift_range=0.5,
                                   height_shift_range=0.5,
                                   horizontal_flip=True,
                                   fill_mode='nearest')

validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_directory,
                                                    color_mode='grayscale',
                                                    target_size=(Img_Height, Img_width),
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=True)

validation_generator = validation_datagen.flow_from_directory(validation_directory,
                                                              color_mode='grayscale',
                                                              target_size=(Img_Height, Img_width),
                                                              batch_size=batch_size,
                                                              class_mode='categorical',
                                                              shuffle=True)


model = Sequential()

# Block-1: The First Convolutional Block

model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', 
                 kernel_initializer='he_normal',
                 activation="elu", 
                 input_shape=(Img_Height, Img_width, 1), 
                 name="Conv1"))

model.add(BatchNormalization(name="Batch_Norm1"))

model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', 
                 kernel_initializer='he_normal', 
                 activation="elu", name="Conv2"))

model.add(BatchNormalization(name="Batch_Norm2"))
model.add(MaxPooling2D(pool_size=(2,2), name="Maxpool1"))
model.add(Dropout(0.2, name="Dropout1"))

# Block-2: The Second Convolutional Block

model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', 
                 kernel_initializer='he_normal',
                 activation="elu", name="Conv3"))

model.add(BatchNormalization(name="Batch_Norm3"))

model.add(Conv2D(filters=64,kernel_size=(3,3),padding='same',
                 kernel_initializer='he_normal', 
                 activation="elu", name="Conv4"))

model.add(BatchNormalization(name="Batch_Norm4"))
model.add(MaxPooling2D(pool_size=(2,2), name="Maxpool2"))
model.add(Dropout(0.2, name="Dropout2"))

# Block-3: The Third Convolutional Block

model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', 
                 kernel_initializer='he_normal', 
                 activation="elu", name="Conv5"))

model.add(BatchNormalization(name="Batch_Norm5"))

model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', 
                 kernel_initializer='he_normal',
                 activation="elu", name="Conv6"))

model.add(BatchNormalization(name="Batch_Norm6"))
model.add(MaxPooling2D(pool_size=(2,2), name="Maxpool3"))
model.add(Dropout(0.2, name="Dropout3"))

# Block-4: The Fully Connected Block

model.add(Flatten(name="Flatten"))
model.add(Dense(64, activation="elu", kernel_initializer='he_normal', name="Dense"))
model.add(BatchNormalization(name="Batch_Norm7"))
model.add(Dropout(0.5, name="Dropout4"))

# Block-5: The Output Block

model.add(Dense(num_classes, activation="softmax", kernel_initializer='he_normal', name = "Output"))




from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import TensorBoard

checkpoint = ModelCheckpoint("emotions.h5", monitor='accuracy', verbose=1,
                              save_best_only=True, mode='auto', period=1)

reduce = ReduceLROnPlateau(monitor='accuracy', factor=0.2, patience=10, 
                           min_lr=0.0001, verbose = 1)

logdir='logs'
tensorboard_Visualization = TensorBoard(log_dir=logdir, histogram_freq=False)



model.compile(loss='categorical_crossentropy',
              optimizer = Adam(lr = 0.001),
              metrics=['accuracy'])


train_samples = 28353
validation_samples = 3534
epochs = 150
batch_size = 64

model.fit(train_generator,
          steps_per_epoch = train_samples//batch_size,
          epochs = epochs,
          callbacks = [checkpoint, reduce, tensorboard_Visualization],
          validation_data = validation_generator,
          validation_steps = validation_samples//batch_size,
          shuffle=True)


#model.save('drive/MyDrive/probe/saved_model/my_model') 
#model.save('drive/MyDrive/emotion.h5')
#Sequential.save('drive/MyDrive/emotion.h5')


model.save('drive/MyDrive/probes/saved_model/my_model')
# Out:
# Found 28273 images belonging to 6 classes.
# Found 7067 images belonging to 6 classes.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/150
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 443/443 [==============================] - ETA: 0s - loss: 2.1701 - accuracy: 0.1945
# Epoch 00001: accuracy improved from -inf to 0.19455, saving model to emotions.h5
# 443/443 [==============================] - 227s 510ms/step - loss: 2.1701 - accuracy: 0.1945 - val_loss: 1.7298 - val_accuracy: 0.2636 - lr: 0.0010
# Epoch 2/150
# 443/443 [==============================] - ETA: 0s - loss: 1.8668 - accuracy: 0.2101
# Epoch 00002: accuracy improved from 0.19455 to 0.21007, saving model to emotions.h5
# ...
